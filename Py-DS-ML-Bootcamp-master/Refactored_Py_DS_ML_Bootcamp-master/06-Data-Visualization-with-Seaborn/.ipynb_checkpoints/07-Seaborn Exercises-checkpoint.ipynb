# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___
# # Seaborn Exercises
#
# Time to practice your new seaborn skills! Try to recreate the plots below (don't worry about color schemes, just the plot itself.

# %% [markdown]
# ## The Data
#
# We will be working with a famous titanic data set for these exercises. Later on in the Machine Learning section of the course, we will revisit this data, and use it to predict survival rates of passengers. For now, we'll just focus on the visualization of the data with seaborn:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
g=sns.JointGrid(x="fare",y="age",data=titanic,xlim=(-100,600),ylim=(0,80))
g.plot(sns.scatterplot,sns.histplot)

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.histplot(x="fare",data=titanic,color=sns.color_palette("bright6").as_hex()[5])
# Out:
# <AxesSubplot: xlabel='fare', ylabel='Count'>

# %%
sns.displot(x="fare",data=titanic,color=sns.color_palette("bright6").as_hex()[5])

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.boxplot(data=titanic,x="class",y="age",palette=sns.color_palette("pastel6").as_hex())
# Out:
# <AxesSubplot: xlabel='class', ylabel='age'>

# %%
sns.boxplot(x='class',y='age',data=titanic,palette='rainbow')
# Out:
# <AxesSubplot: xlabel='class', ylabel='age'>

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.swarmplot(x="class",y="age",data=titanic,size=4,palette="husl")
# Out:
# /tmp/ipykernel_3592/2722014419.py:5: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x="class",y="age",data=titanic,size=4,palette="husl")
# <AxesSubplot: xlabel='class', ylabel='age'>

# %%
sns.swarmplot(x="class",y="age",data=titanic,size=4,palette="Set2")
# Out:
# /tmp/ipykernel_3592/2853045288.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x="class",y="age",data=titanic,size=4,palette="Set2")
# <AxesSubplot: xlabel='class', ylabel='age'>

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.histplot(x="sex",data=titanic,shrink=.8,palette=["#5ac750","red"],hue="alive")
# Out:
# <AxesSubplot: xlabel='sex', ylabel='Count'>

# %%
sns.countplot(x='sex',data=titanic)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
titanic_corr=titanic.corr()
sns.heatmap(titanic_corr,cmap="coolwarm",annot=True)
# Out:
# /tmp/ipykernel_3592/2676666544.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   titanic_corr=titanic.corr()
# <AxesSubplot: >

# %%
sns.heatmap(titanic_corr,cmap="coolwarm")
plt.title("titanic.corr()")
# Out:
# Text(0.5, 1.0, 'titanic.corr()')

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
g=sns.FacetGrid(titanic,col="sex")
g.map(sns.histplot,"age")

# %%
g=sns.FacetGrid(titanic,col="sex")
g.map(plt.hist,"age")

# %% [markdown]
# # Great Job!
#
# ### That is it for now! We'll see a lot more of seaborn practice problems in the machine learning section!
