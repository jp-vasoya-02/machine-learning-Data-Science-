# %%
import pandas as pd

# %%
df=pd.read_csv("Donation_data.csv").dropna(axis=1,thresh=4)
df
# Out:
#         Party                    Name    Type  \
# 0         CPI              Aziz Pasha  Others
# 1      CPI(M)        V K Ramachandran  Others
# 2         INC      Dr. Manmohan Singh  Others
# 3         INC     Dr. Manda Jagnathan  Others
# 4         INC        Prof. K.V.Thomas  Others
# ...       ...                     ...     ...
# 13568     BJP        Zydus Healthcare  Others
# 13569     BJP  Zydus Wellness Limited  Others
# 13570     BJP  Zydus Wellness Limited  Others
# 13571     BJP  Zydus Wellness Limited  Others
# 13572     NCP  Zydus Wellness -Sikkim  Others
#
#                                                  Address PAN Given  \
# 0                      16-B, Ferozeshah Road New Delhi-1         Y
# 1      No.1, First Floor Main Road Domlur Second Stag...         Y
# 2                       3, Motilal Nehru Place New Delhi         N
# 3                            9,Firozshah Road New Delhi          N
# 4                         17,Dr.B.R.Mehta Lane New Delhi         N
# ...

# %%
df["Amount_number"]=float(df.loc[0,"Amount"].split("₹")[1].strip().replace(',',''))

# %%
df["Amount_number"]=df["Amount"].apply(lambda a:float(a.split("₹")[1].strip().replace(',','')))

# %%
df
# Out:
#         Party                    Name    Type  \
# 0         CPI              Aziz Pasha  Others
# 1      CPI(M)        V K Ramachandran  Others
# 2         INC      Dr. Manmohan Singh  Others
# 3         INC     Dr. Manda Jagnathan  Others
# 4         INC        Prof. K.V.Thomas  Others
# ...       ...                     ...     ...
# 13568     BJP        Zydus Healthcare  Others
# 13569     BJP  Zydus Wellness Limited  Others
# 13570     BJP  Zydus Wellness Limited  Others
# 13571     BJP  Zydus Wellness Limited  Others
# 13572     NCP  Zydus Wellness -Sikkim  Others
#
#                                                  Address PAN Given  \
# 0                      16-B, Ferozeshah Road New Delhi-1         Y
# 1      No.1, First Floor Main Road Domlur Second Stag...         Y
# 2                       3, Motilal Nehru Place New Delhi         N
# 3                            9,Firozshah Road New Delhi          N
# 4                         17,Dr.B.R.Mehta Lane New Delhi         N
# ...

# %%
df["Amount_number"].max()
# Out:
# 500000000.0

# %%
df["Amount"].max()
# Out:
# ' ₹  990,000.00 '

# %%
top_10_donator=df.sort_values("Amount_number",ascending=False).head(10)
top_10_donator
# Out:
#      Party                     Name             Type  \
# 3095   BJP  General Electoral Trust  Electoral Trust
# 3138   INC  General Electoral Trust  Electoral Trust
# 9082   BJP    Satya Electoral Trust  Electoral Trust
# 9083   BJP    Satya Electoral Trust  Electoral Trust
# 9085   BJP    Satya Electoral Trust  Electoral Trust
# 9084   BJP    Satya Electoral Trust  Electoral Trust
# 9099   INC    Satya Electoral Trust  Electoral Trust
# 9100   INC    Satya Electoral Trust  Electoral Trust
# 9086   BJP    Satya Electoral Trust  Electoral Trust
# 9087   BJP    Satya Electoral Trust  Electoral Trust
#
#                                                 Address PAN Given  \
# 3095                                                 --         N
# 3138  B-4, Aditya Birla Centre S.K. Ahire Marg Worli...         N
# 9082  G-15, Hans Bhawan,1 Bahadur Shah Zafar Marg Ne...         Y
# 9083                                                 --         Y
# ...

# %%
df
# Out:
#         Party                    Name    Type  \
# 0         CPI              Aziz Pasha  Others
# 1      CPI(M)        V K Ramachandran  Others
# 2         INC      Dr. Manmohan Singh  Others
# 3         INC     Dr. Manda Jagnathan  Others
# 4         INC        Prof. K.V.Thomas  Others
# ...       ...                     ...     ...
# 13568     BJP        Zydus Healthcare  Others
# 13569     BJP  Zydus Wellness Limited  Others
# 13570     BJP  Zydus Wellness Limited  Others
# 13571     BJP  Zydus Wellness Limited  Others
# 13572     NCP  Zydus Wellness -Sikkim  Others
#
#                                                  Address PAN Given  \
# 0                      16-B, Ferozeshah Road New Delhi-1         Y
# 1      No.1, First Floor Main Road Domlur Second Stag...         Y
# 2                       3, Motilal Nehru Place New Delhi         N
# 3                            9,Firozshah Road New Delhi          N
# 4                         17,Dr.B.R.Mehta Lane New Delhi         N
# ...

# %%
top_10_donator.reset_index().to_excel("top_10_donator.xlsx",sheet_name="Top 10")
top_10_donator
# Out:
#      Party                     Name             Type  \
# 3095   BJP  General Electoral Trust  Electoral Trust
# 3138   INC  General Electoral Trust  Electoral Trust
# 9082   BJP    Satya Electoral Trust  Electoral Trust
# 9083   BJP    Satya Electoral Trust  Electoral Trust
# 9085   BJP    Satya Electoral Trust  Electoral Trust
# 9084   BJP    Satya Electoral Trust  Electoral Trust
# 9099   INC    Satya Electoral Trust  Electoral Trust
# 9100   INC    Satya Electoral Trust  Electoral Trust
# 9086   BJP    Satya Electoral Trust  Electoral Trust
# 9087   BJP    Satya Electoral Trust  Electoral Trust
#
#                                                 Address PAN Given  \
# 3095                                                 --         N
# 3138  B-4, Aditya Birla Centre S.K. Ahire Marg Worli...         N
# 9082  G-15, Hans Bhawan,1 Bahadur Shah Zafar Marg Ne...         Y
# 9083                                                 --         Y
# ...

# %%
top_10_donator.drop(axis=1,columns="Amount_number",inplace=True)

# %%
top_10_donator.reset_index()
# Out:
#    index Party                     Name             Type  \
# 0   3095   BJP  General Electoral Trust  Electoral Trust
# 1   3138   INC  General Electoral Trust  Electoral Trust
# 2   9082   BJP    Satya Electoral Trust  Electoral Trust
# 3   9083   BJP    Satya Electoral Trust  Electoral Trust
# 4   9085   BJP    Satya Electoral Trust  Electoral Trust
# 5   9084   BJP    Satya Electoral Trust  Electoral Trust
# 6   9099   INC    Satya Electoral Trust  Electoral Trust
# 7   9100   INC    Satya Electoral Trust  Electoral Trust
# 8   9086   BJP    Satya Electoral Trust  Electoral Trust
# 9   9087   BJP    Satya Electoral Trust  Electoral Trust
#
#                                              Address PAN Given  \
# 0                                                 --         N
# 1  B-4, Aditya Birla Centre S.K. Ahire Marg Worli...         N
# 2  G-15, Hans Bhawan,1 Bahadur Shah Zafar Marg Ne...         Y
# 3                                                 --         Y
# ...

# %%
top_10_donator.reset_index().drop(columns="index",axis=1)
# Out:
#   Party                     Name             Type  \
# 0   BJP  General Electoral Trust  Electoral Trust
# 1   INC  General Electoral Trust  Electoral Trust
# 2   BJP    Satya Electoral Trust  Electoral Trust
# 3   BJP    Satya Electoral Trust  Electoral Trust
# 4   BJP    Satya Electoral Trust  Electoral Trust
# 5   BJP    Satya Electoral Trust  Electoral Trust
# 6   INC    Satya Electoral Trust  Electoral Trust
# 7   INC    Satya Electoral Trust  Electoral Trust
# 8   BJP    Satya Electoral Trust  Electoral Trust
# 9   BJP    Satya Electoral Trust  Electoral Trust
#
#                                              Address PAN Given  \
# 0                                                 --         N
# 1  B-4, Aditya Birla Centre S.K. Ahire Marg Worli...         N
# 2  G-15, Hans Bhawan,1 Bahadur Shah Zafar Marg Ne...         Y
# 3                                                 --         Y
# 4                                                 --         Y
# ...

# %%
pd.read_html("https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list")[0]
# Out:
#                          Bank NameBank           CityCity StateSt  CertCert  \
# 0                    Almena State Bank             Almena      KS     15426
# 1           First City Bank of Florida  Fort Walton Beach      FL     16748
# 2                 The First State Bank      Barboursville      WV     14361
# 3                   Ericson State Bank            Ericson      NE     18265
# 4     City National Bank of New Jersey             Newark      NJ     21111
# ..                                 ...                ...     ...       ...
# 558                 Superior Bank, FSB           Hinsdale      IL     32646
# 559                Malta National Bank              Malta      OH      6629
# 560    First Alliance Bank & Trust Co.         Manchester      NH     34264
# 561  National State Bank of Metropolis         Metropolis      IL      3815
# 562                   Bank of Honolulu           Honolulu      HI     21029
#
# ...

# %%
pd.read_html("https://www.w3schools.com/html/html_tables.asp")[0]
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy
