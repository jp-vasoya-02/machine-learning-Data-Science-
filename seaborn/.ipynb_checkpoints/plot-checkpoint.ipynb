# %%
import seaborn as sns

# %%
data=sns.load_dataset("titanic")
data.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
sns.displot(data["fare"],bins=20,)

# %%
import pandas as pd
import seaborn as sns
import numpy as np

df = pd.DataFrame(np.random.poisson(10,(20,3)),
                  columns=['Knn', 'Kss', 'Ktt'])

df_CohBeh = pd.melt(df, value_vars=['Knn', 'Kss', 'Ktt'], var_name='melt')

sns.displot(data=df_CohBeh, hue='melt',x='value',
            kind="kde", fill=True, legend=False, height=5, aspect=1.6, 
            cut=0, bw_adjust=1)

# %%
sns.jointplot(x="fare",y="age",data=data,kind="reg")

# %%
sns.pairplot(data,hue="sex")

# %%
sns.rugplot(data["class"])
# Out:
# <AxesSubplot: xlabel='survived'>

# %%
sns.kdeplot(data["survived"])
# Out:
# <AxesSubplot: xlabel='survived', ylabel='Density'>

# %%
sns.jointplot(x="age",y="survived",data=data,hue="sex")

# %%
# Categorial Plots

# %%
sns.barplot(x="fare",y="embark_town",data=data,hue="sex",estimator=max)
# Out:
# <AxesSubplot: xlabel='fare', ylabel='embark_town'>

# %%
sns.countplot(x="embark_town",data=data,hue="who")
# Out:
# <AxesSubplot: xlabel='embark_town', ylabel='count'>

# %%
sns.boxplot(x="fare",y="class",data=data)
# Out:
# <AxesSubplot: xlabel='fare', ylabel='class'>

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.violinplot(y="parch",x="embarked",data=data)
# Out:
# <AxesSubplot: xlabel='embarked', ylabel='parch'>

# %%
data[data["parch"]>5]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 678         0       3  female  43.0      1      6  46.9        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 678  woman       False  NaN  Southampton    no  False

# %%
sns.stripplot(x="who",y="alone",data=data,hue="alive")
# Out:
# <AxesSubplot: xlabel='who', ylabel='alone'>

# %%
sns.swarmplot(x="age",y="deck",data=data,hue="adult_male")
# Out:
# <AxesSubplot: xlabel='age', ylabel='deck'>
